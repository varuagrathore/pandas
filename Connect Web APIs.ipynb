# %% [markdown]
# **Install HTTP Requests Package**

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# **Make API Requests and Retrieve Data**

# %%
import requests
api_url = 'https://jsonplaceholder.typicode.com/posts'
response = requests.get(api_url)
if response.status_code == 200:
    json_data = response.json()
else:
    print(f'Error: Unable to fetch data from the API (status code:{response.status_code})')

# %%
import pandas as pd
# Load the JSON data into a DataFrame
#data = pd.DataFrame(json_data)
# Alternatively, you can use the 'pd.read_json()' function
data = pd.read_json(api_url)

# %%
data
# Out:
#     userId   id                                              title  \
# 0        1    1  sunt aut facere repellat provident occaecati e...
# 1        1    2                                       qui est esse
# 2        1    3  ea molestias quasi exercitationem repellat qui...
# 3        1    4                               eum et est occaecati
# 4        1    5                                 nesciunt quas odio
# ..     ...  ...                                                ...
# 95      10   96  quaerat velit veniam amet cupiditate aut numqu...
# 96      10   97         quas fugiat ut perspiciatis vero provident
# 97      10   98                        laboriosam dolor voluptates
# 98      10   99  temporibus sit alias delectus eligendi possimu...
# 99      10  100              at nam consequatur ea labore ea harum
#
#                                                  body
# 0   quia et suscipit\nsuscipit recusandae consequu...
# ...

# %% [markdown]
# **Perform Data Manipulation and Analysis**

# %% [markdown]
# the process for connecting to different APIs may vary
#  depending on the specific API and the required authentication methods. You
#  may need to provide API keys, tokens, or use OAuth for authentication. Be
#  sure to consult the API documentation for detailed instructions on how to
#  connect and retrieve data.

# %% [markdown]
# **Data Scraping**

# %%
# Install Beautful Soup Package
# !pip install beautifulsoup4 requests
# Out:
# ...
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests

# %%
url = 'https://www.worldcoinindex.com/'

# %%
#Fetch the HTML content
response = requests.get(url)

#Check if the requests was successful
if response.status_code ==  200:
    html_content = response.text
else:
    print(f'Error: Unable to fetch data from the website (status code:{response.status_code})')

# %%
from bs4 import BeautifulSoup

#Parse the HTML content

soup = BeautifulSoup(html_content,'html.parser')

table = soup.find('table',{'id': 'myTable'})

# %%
html_content
# Out:
# '\r\n<!DOCTYPE html>\n<html style="background-color: #FFF">\n<head>\n<meta http-equiv="Content-Type" content="text/html">\n<meta name="mobile-web-app-capable" content="yes">\n<meta charset="utf-8" />\n<meta name="description" content="Cryptocoins ranked by 24hr trading volume, price info, charts, market cap and news" />\n<meta name="keywords" content="Coin, index, worldcoin, coinindex, worldindex, cryptocoins, crypto, traded, exchanges, ranked, marketcap, coins, cryptocurrency ,coinprices, price, last trade time, trade, market cap, trading, traded, volume, rate, buy cryptocurrency, sell cryptocurrency" />\n<meta name="viewport" content="width=device-width, initial-scale=1, user-scalable = no">\n<meta name="apple-mobile-web-app-capable" content="yes" />\n<meta name="propeller" content="efad6eed15cdd45139ef34d287cc06ff" />\n<meta property="og:image" content="https://www.worldcoinindex.com/content/img/worldcoinindex_social.png?v=3" />\n<title>Cryptocoin price index and market cap - Worl
# ...

# %%
table
# Out:
# <table class="tablesorter" data-test="test" id="myTable">
# <thead>
# <tr>
# <th class="rank headerrank header-off">#</th>
# <th class="bitcoinLogo header-off"></th>
# <th class="bitcoinName header-off">Name</th>
# <th class="ticker1 header-off" style="text-align: left;">Ticker</th>
# <th class="sortoff lastprice headerlastprice">Last price</th>
# <th class="header-off">%</th>
# <th class="header-off mob-hide-col highpriceheader">24 high</th>
# <th class="header-off mob-hide-col lowpriceheader">24 low</th>
# <th class="headerGraph mob-hide-col chartheader" data-sorter="false">Price Charts 7d</th>
# <th class="headVolume mob-hide-col volumeheader" style="background-position-x: 90px !important;">24 volume</th>
# <th class="headcoins header-off mob-hide-col coinsheader"># Coins</th>
# <th class="headMarketcap header-off mob-hide-col marketcapheader">Market cap</th>
# </tr>
# </thead>
# <tbody>
# <tr class="ethereum coinzoeken" data-naam="ethereum" data-symbol="563">
# ...

# %%
# Parse the HTML with BeautifulSoup
soup = BeautifulSoup(html_content, 'html.parser')

# Find the table
table = soup.find('table', {'id': 'myTable'})

# Extract headers
headers = [header.text.strip() for header in table.find_all('th')]

# Extract rows
rows = table.find('tbody').find_all('tr')

# Extract data
data = []
for row in rows:
    cells = row.find_all('td')
    data.append([cell.get_text(strip=True) for cell in cells])

# Create DataFrame
df = pd.DataFrame(data, columns=headers)

# Display the DataFrame
df
# Out:
#        #            Name Ticker Last price        %    24 high     24 low  \
# 0      1        Ethereum    ETH  $3,724.22   -0.31%  $3,941.44  $3,708.74
# 1      2         Bitcoin    BTC    $67,064   -3.01%    $70,017    $66,737
# 2      3          Solana    SOL    $171.55   -3.01%    $179.10    $169.30
# 3      4            Pepe   PEPE  $0.000013   +0.39%  $0.000015  $0.000013
# 4      5        Usd coin   USDC      $1.00   +0.12%      $1.01  $0.996591
# ..   ... ..          ...    ...        ...      ...        ...        ...
# 97    96             Ren    REN  $0.060548  -10.74%  $0.089721  $0.060326
# 98    97          Monero    XMR    $139.09   +0.58%    $140.17    $136.58
# 99    98            Core   CORE      $1.57   -7.06%      $1.70      $1.56
# 100   99     Immutable X    IMX      $2.38   -5.49%      $2.60      $2.37
# 101  100       Dymension    DYM      $2.58   -5.63%      $2.86      $2.57
#
#     Price Charts 7d 24 volume  # Coins Market cap
# ...
