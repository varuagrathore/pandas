# %%
import pandas as pd

# %%
data = pd.read_csv(r"E:\archive (2)\AER_credit_card_data.csv")

# %%
data
# Out:
#      card  reports       age  income     share  expenditure owner selfemp  \
# 0     yes        0  37.66667  4.5200  0.033270   124.983300   yes      no
# 1     yes        0  33.25000  2.4200  0.005217     9.854167    no      no
# 2     yes        0  33.66667  4.5000  0.004156    15.000000   yes      no
# 3     yes        0  30.50000  2.5400  0.065214   137.869200    no      no
# 4     yes        0  32.16667  9.7867  0.067051   546.503300   yes      no
# ...   ...      ...       ...     ...       ...          ...   ...     ...
# 1314  yes        0  33.58333  4.5660  0.002146     7.333333   yes      no
# 1315   no        5  23.91667  3.1920  0.000376     0.000000    no      no
# 1316  yes        0  40.58333  4.6000  0.026513   101.298300   yes      no
# 1317  yes        0  32.83333  3.7000  0.008999    26.996670    no     yes
# 1318  yes        0  48.25000  3.7000  0.111619   344.157500   yes      no
#
#       dependents  months  majorcards  active
# ...

# %% [markdown]
# **Rename Columns (optional)**

# %%
#If you want to rename columns for better readability or consistency, you can use the rename() method:

data = data.rename(columns={
    'card' : ' Card',
    'reports':' Reports',
    'age':'Age',
    'income':'Income',
    'share':'Share',	
    'expenditure':'Expenditure',
    'owner':'Owner',	
    'selfemp':'Selfemp',
    'dependents':'Dependents',
    'months': 'Months',
    'majorcards':'Majorcards',	
    'active':'Active'
})

# %%
data
# Out:
#       Card   Reports       Age  Income     Share  Expenditure Owner Selfemp  \
# 0      yes         0  37.66667  4.5200  0.033270   124.983300   yes      no
# 1      yes         0  33.25000  2.4200  0.005217     9.854167    no      no
# 2      yes         0  33.66667  4.5000  0.004156    15.000000   yes      no
# 3      yes         0  30.50000  2.5400  0.065214   137.869200    no      no
# 4      yes         0  32.16667  9.7867  0.067051   546.503300   yes      no
# ...    ...       ...       ...     ...       ...          ...   ...     ...
# 1314   yes         0  33.58333  4.5660  0.002146     7.333333   yes      no
# 1315    no         5  23.91667  3.1920  0.000376     0.000000    no      no
# 1316   yes         0  40.58333  4.6000  0.026513   101.298300   yes      no
# 1317   yes         0  32.83333  3.7000  0.008999    26.996670    no     yes
# 1318   yes         0  48.25000  3.7000  0.111619   344.157500   yes      no
#
#       Dependents  Months  Majorcards  Active
# ...

# %% [markdown]
# **Convert Data Types**

# %%
data.dtypes
# Out:
#  Card           object
#  Reports         int64
# Age            float64
# Income         float64
# Share          float64
# Expenditure    float64
# Owner           object
# Selfemp         object
# Dependents       int64
# Months           int64
# Majorcards       int64
# Active           int64
# dtype: object

# %%
sns.scatterplot(data['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
#If you need to change the data type of a column, you can use the astype()  method

# %% [markdown]
# **Remove Duplicates**

# %%
duplicates = data.duplicated()

# %%
duplicates.sum()
# Out:
# 0

# %%
#data.drop_duplicates()

# %% [markdown]
# **Normalize Numerical Columns**

# %%
#normalization adn standarization define a fixed range for our dataset
#To normalize a column (scale values between 0 and 1):
import seaborn as sns
import matplotlib.pyplot as plt
data['Age_Scaled'] = (data['Age'] - data['Age'].min()) / ( data['Age'].max() - data['Age'].min())

# %%
# Create subplots
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
# Plot original 'Age'
sns.histplot(data['Age'], bins=10, kde=True, ax=axes[0])
axes[0].set_title('Original Age Distribution')

# Plot scaled 'Age'
sns.histplot(data['Income'], bins=10, kde=True, ax=axes[1])
axes[1].set_title('Scaled Age Distribution')
# Out:
# Text(0.5, 1.0, 'Scaled Age Distribution')

# %% [markdown]
# **Encode Categorical Variables**

# %%
data.columns = data.columns.str.strip()

# %%
import pandas as pd

# Assuming 'data' is your DataFrame
data = pd.get_dummies(data, columns=['Card', 'Owner', 'Selfemp'])

# %%
data
# Out:
#       Reports       Age  Income     Share  Expenditure  Dependents  Months  \
# 0           0  37.66667  4.5200  0.033270   124.983300           3      54
# 1           0  33.25000  2.4200  0.005217     9.854167           3      34
# 2           0  33.66667  4.5000  0.004156    15.000000           4      58
# 3           0  30.50000  2.5400  0.065214   137.869200           0      25
# 4           0  32.16667  9.7867  0.067051   546.503300           2      64
# ...       ...       ...     ...       ...          ...         ...     ...
# 1314        0  33.58333  4.5660  0.002146     7.333333           0      94
# 1315        5  23.91667  3.1920  0.000376     0.000000           3      12
# 1316        0  40.58333  4.6000  0.026513   101.298300           2       1
# 1317        0  32.83333  3.7000  0.008999    26.996670           0      60
# 1318        0  48.25000  3.7000  0.111619   344.157500           2       2
#
# ...

# %%
#For label encoding, you can use the LabelEncoder class from scikit-learn:
#from sklearn.preprocessing import LabelEncoder
#encoder = LabelEncoder()
#data['Surname'] = encoder.fit_transform(data['a'])


#Converts each unique category value into a numerical value.
#Each category is assigned an integer value.
