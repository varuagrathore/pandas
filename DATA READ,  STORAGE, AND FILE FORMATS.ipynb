# %%
import pandas as pd

# %%
data_json=pd.read_json(r"C:\Users\dell\Downloads\archive (1)\iris.json")

# %%
data_json
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth    species
# 0            5.1         3.5          1.4         0.2     setosa
# 1            4.9         3.0          1.4         0.2     setosa
# 2            4.7         3.2          1.3         0.2     setosa
# 3            4.6         3.1          1.5         0.2     setosa
# 4            5.0         3.6          1.4         0.2     setosa
# ..           ...         ...          ...         ...        ...
# 145          6.7         3.0          5.2         2.3  virginica
# 146          6.3         2.5          5.0         1.9  virginica
# 147          6.5         3.0          5.2         2.0  virginica
# 148          6.2         3.4          5.4         2.3  virginica
# 149          5.9         3.0          5.1         1.8  virginica
#
# [150 rows x 5 columns]

# %%
 pip install openpyxl xlrd
# Out:
# ...
#    ---------------------------------------- 0.0/250.0 kB ? eta -:--:--
#    ------ --------------------------------- 41.0/250.0 kB 2.0 MB/s eta 0:00:01
#    -------------- ------------------------- 92.2/250.0 kB 1.3 MB/s eta 0:00:01
#    -------------- ------------------------- 92.2/250.0 kB 1.3 MB/s eta 0:00:01
#    -------------- ------------------------- 92.2/250.0 kB 1.3 MB/s eta 0:00:01
#    -------------------------- ----------- 174.1/250.0 kB 751.6 kB/s eta 0:00:01
#    -------------------------- ----------- 174.1/250.0 kB 751.6 kB/s eta 0:00:01
#    ----------------------------- -------- 194.6/250.0 kB 620.6 kB/s eta 0:00:01
#    ----------------------------- -------- 194.6/250.0 kB 620.6 kB/s eta 0:00:01
#    ----------------------------- -------- 194.6/250.0 kB 620.6 kB/s eta 0:00:01
#    ----------------------------- -------- 194.6/250.0 kB 620.6 kB/s eta 0:00:01
#    ----------------------------- -------- 194.6/250.0 kB 620.6 kB/s eta 0:00:01
# ...

# %%
data_excel=pd.read_excel(r"C:\Users\dell\Downloads\Python\excel\GradeBookSummer18.xlsx")

# %%
data_excel
# Out:
#       Name      Quiz1      Quiz2  Quiz3       Test1       Test2       Test3  \
# 0      Max  20.000000  20.000000     20  100.000000  100.000000  100.000000
# 1     siou  18.000000  20.000000     19   99.000000   96.000000   88.000000
# 2      ava  20.000000  15.000000     18   98.000000   87.000000   99.000000
# 3    chris  19.000000  12.000000     17   78.000000   67.000000   77.000000
# 4    steve  17.000000  11.000000     16   89.000000   89.000000   66.000000
# 5    roger  16.000000  14.000000     17   67.000000   90.000000   56.000000
# 6     Gigi  15.000000  17.000000     19   87.000000   80.000000   65.000000
# 7     peio  19.000000  18.000000     20   97.000000   70.000000   75.000000
# 8  Average  17.714286  15.285714     18   87.857143   82.714286   75.142857
#
#    Total    %Grade
# 0  360.0       NaN
# 1  340.0  0.944444
# 2  337.0  0.936111
# 3  270.0  0.750000
# 4  288.0  0.800000
# 5  260.0  0.722222
# 6  283.0  0.786111
# 7  299.0  0.830556
# 8    NaN       NaN

# %% [markdown]
# you can use the same function to inpect this type of data that use for csv file there is no differnce between this and csv file data only difference is how you store data according to your need and comfort

# %% [markdown]
# **Writing Data to Different Formats**

# %%
# Write to JSON Format
#you can use path to save the file means where you want to save 
#i am not assigning any path in my code because i save this in same folder where my .ipynb file is saved so no need to assign path
#otherwise if you want to store in some other file then provide path of that particular folder

data_excel.to_json('data_excel.json',index=False)

# %%
#Write to Excel (XLSX) Format
data_json.to_excel('data_json.xlsx',index=False,engine='openpyxl')

# %%
#To write the DataFrame to an HTML file, you can use the to_html() method
data_excel.to_html('data_excel.html',index=False)

# %%
pip install pyarrow
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting pyarrow
# ...
#    ---------------------------------------- 0.0/25.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/25.9 MB 1.4 MB/s eta 0:00:19
#    ---------------------------------------- 0.0/25.9 MB 1.4 MB/s eta 0:00:19
#    ---------------------------------------- 0.0/25.9 MB 1.4 MB/s eta 0:00:19
#    ---------------------------------------- 0.1/25.9 MB 297.7 kB/s eta 0:01:27
#    ---------------------------------------- 0.1/25.9 MB 420.8 kB/s eta 0:01:02
#    ---------------------------------------- 0.2/25.9 MB 541.0 kB/s eta 0:00:48
#    ---------------------------------------- 0.2/25.9 MB 722.1 kB/s eta 0:00:36
#    ---------------------------------------- 0.3/25.9 MB 855.7 kB/s eta 0:00:30
#     --------------------------------------- 0.4/25.9 MB 958.4 kB/s eta 0:00:27
#     --------------------------------------- 0.5/25.9 MB 1.0 MB/s eta 0:00:25
# ...

# %%
data_excel.to_parquet('data_excel.parquet',index=False,engine='pyarrow')

# %% [markdown]
# **These are just a few examples of the output formats supported by Pandas**

# %% [markdown]
# **what i saw in writing in different formats is using name of the dataframe.to_(particular format name json excel csv stata like to_stata etc)**
